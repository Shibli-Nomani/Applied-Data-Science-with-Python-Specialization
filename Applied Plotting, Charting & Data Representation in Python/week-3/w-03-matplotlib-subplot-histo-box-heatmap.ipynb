# %% [markdown]
# # Subplot

# %% [markdown]
# 1. number of rows
# 2. number of cols
# 3. plot numbers
#
# Two plots side by side (1,2,1) and (1,2,2)

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
#plt.subplot? --to check the docs of subplot

# %% [markdown]
# # linear line in first plot

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,2,1)
linear_data = np.array([2,3,4,5,6,7,8,9])
plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # exponential line in second plot

# %%
exponential_data = linear_data**2
plt.subplot(1,2,2)
plt.plot(exponential_data, '--o')

# %% [markdown]
# # exponential line in first plot where linear plot has already exist

# %%
#plt.subplot(1,2,1)
#plt.plot(exponential_data, '-x')

# %% [markdown]
# # loc axis between two plots (`sharey`) with same y scaling

# %% [markdown]
# gca = get the current axis
#
# gcf = get the current figure

# %%
plt.figure()
ax1 = plt.subplot(1,2,1)
plt.plot(linear_data, '-o')

ax2 = plt.subplot(1,2,2, sharey = ax1)
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.subplot(1,2,1) == plt.subplot(121)
# Out:
# <img src="data:image/png;base64,..." width="640">
# True

# %% [markdown]
# # share X and share Y for multiple plots using iterative way

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3,
                                                                        sharex = True,
                                                                        sharey = True
                                                                       )
plt.plot(linear_data)
#here all  x axes are sharing each oher for scaling and y axes are sharing each oher for scaling
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # for labeling the axis x and y
#
# to do this, we need to perform iteration for labeling

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3,
                                                                        sharex = True,
                                                                        sharey = True
                                                                       )
plt.plot(linear_data)
#here all  x axes are sharing each oher for scaling and y axes are sharing each oher for scaling
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
#alternative

plt.gcf().canvas.draw()

# %% [markdown]
# # Histogram

# %% [markdown]
# histogram is a bar chart to show the distribution of datapoints
#
# 1. Random 2. Uniform 3. Chi-Square Distribution
#
# x-axis is giving distribution and y-axis is frequency of distribution

# %%
fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)

axs = [ax1, ax2, ax3, ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    
    sample = np.random.normal(loc =0.0, scale =1.0, size = sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs

# %% [markdown]
# <h2>Histogram 10 Bins</h2>
#
# By default, histogram uses 10 bins which means 10 different products. That's why we are seeing some variation in plot

# %% [markdown]
# # Histogram with 100 bins

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2, 2, sharex =True)

axs = [ax1, ax2, ax3, ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc =0.0, scale = 1.0, size = sample_size)
    axs[n].hist(sample, bins = 100)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2>How much bins is good? It depends<\h2>

# %% [markdown]
# # Normal and Random DDistribution

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale = 1.0, size = 10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec
plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0,1:]) #all of the elemnts start with zero as we are using list
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.random.normal(loc = 0.0, scale =1.0, size = 10000)
X = np.random.random(size=10000)

lower_right.scatter(X,Y)
top_histogram.hist(X,bins=100)
s = side_histogram.hist(Y, bins=100, orientation = 'horizontal')

# %% [markdown]
# <h1>Clear Function</h1>
#
# it will clear previous plotting and replace with new

# %%
import matplotlib.gridspec as gridspec
plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0,1:]) #all of the elemnts start with zero as we are using list
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])


#plotting data as per slicing

Y = np.random.normal(loc = 0.0, scale =1.0, size = 10000)
X = np.random.random(size=10000)

lower_right.scatter(X,Y)
top_histogram.hist(X,bins=100)
s = side_histogram.hist(Y, bins=100, orientation = 'horizontal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#clear the previous data and replace by new
top_histogram.clear()
top_histogram.hist(X, bins=100, normed = True)

side_histogram.clear()
side_histogram.hist(Y, bins =100, orientation = 'horizontal', normed = True)

side_histogram.invert_xaxis() #inversing the x-axis

# %% [markdown]
# # To set the new range in axis and clear the axis

# %%
# To clear it in more refine way

for ax in {top_histogram, lower_right}:
    ax.set_xlim(0,1)

for ax in [side_histogram, lower_right]:
    ax.set_ylim(-5,5)

# %%
# %%HTML
# #<img src ='http://educationxpress.mit.edu/sites/default/files/journal/WP1-Fig13.jpg' />

# %%
# %%HTML
#
# <img src ='https://blog.kakaocdn.net/dn/dOWCob/btqBNjkaKxr/6RDe651wWDAm2EjQTtRQAK/img.png' />
# Out:
# <img src ='https://blog.kakaocdn.net/dn/dOWCob/btqBNjkaKxr/6RDe651wWDAm2EjQTtRQAK/img.png' />

# %% [markdown]
# # BOX PLot and Whisker Plot

# %% [markdown]
# a box plot / whisker plot is a mathod of showing min, max, median with Interquartile range as well as **outliers**

# %%
import numpy as np
import pandas as pd

normal_sample = np.random.normal(loc=0.0, scale =1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size = 10000)

df = pd.DataFrame({'normal': normal_sample,
                  'random': random_sample,
                  'gamma': gamma_sample})

df.head()
# Out:
#       gamma    normal    random
# 0  1.008612  0.552356  0.295736
# 1  2.660456  0.453109  0.436684
# 2  2.501902  1.297559  0.655132
# 3  1.903894 -0.627248  0.415920
# 4  2.462353 -0.360783  0.566244

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       2.017991      0.001117      0.497245
# std        1.422212      0.995514      0.289413
# min        0.008372     -4.099201      0.000016
# 25%        0.973570     -0.675565      0.247522
# 50%        1.690211      0.008705      0.497795
# 75%        2.736860      0.675997      0.747936
# max       13.961171      3.477270      0.999893

# %% [markdown]
# First Quantile = 25% of data
#
# Second Quantile > 25% to = 75%
#
# Third Quantile = 75%
#
# Final = > 75% to = 100%

# %%
plt.figure()

#underscore means unpacking value which we don't care about. We can avoid to show the value
_ = plt.boxplot(df['normal'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Multiple Box Plots

# %%
plt.figure()
plt.clf()

_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range') #whis has been used to avoid outlier
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# note : gamma has very long tail

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Use of mpl_toolkits
#
# to display multiple images in a matplotlib

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range')

ax2 = mpl_il.inset_axes(plt.gca(), width = '60%', height = '40%', loc =2)
ax2.hist(df['gamma'], bins =100)
ax2.margins(x=0.5)

#ax2.yaxis.tick_right() # flip the y-axis scale of histogram
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax2.yaxis.tick_right() # flip the y-axis scale of histogram

# %% [markdown]
# # Outliers

# %%
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6f69a4e7b8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f69a24be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f69a35b00>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f69a30c50>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6f69a9b240>,
# ...
#   <matplotlib.lines.Line2D at 0x7f6f699dfcc0>]}

# %% [markdown]
# # HeatMap

# %% [markdown]
# heatmap works well we have contineous relationship with demensions. It's not good for discontineous dimensions. For categorical data, it misleads the audieance by providing wrong pattern.
#
# In matplotlib heatmap is two dimensional histrogram where X and Y axis show potential data point and color shows the frequency of observation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.figure()
X  = np.random.normal(loc=0.0, scale =1, size=10000)
Y = np.random.random(size=10000)
_ = plt.hist2d(X,Y, bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_ = plt.hist2d(X,Y, bins=25)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Animation

# %% [markdown]
# Matlab has animation and interactivity function. It happens using the backend

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
n = 100
X= np.random.randn(n)

# %% [markdown]
# Now we need create a function for animation which will call the frames within miliseconds start from frame 0

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla() #clear current object
    bins = np.arange(-4, 4, 0.5) #bound the bins -4 to 4with step 0.5
    plt.hist(X[:curr], bins = bins) #set axis value to stop auto scaling
    plt.axis([-4, 4, 0, 30]) #set axis value to stop auto scaling
    plt.gca().set_title('Sampling the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    # place the text at certain position and show how many sample render to the screen
    plt.annotate('n = {}'.format(curr), [3,27])

# %%
fig  = plt.figure()
#constructor = FuncAnimation
#1st Parameter = fig (figure that we want)
#2nd Parameter = update (function we define above)
#3rd Paramter = interval (amount of time we want betwwen update)



a = animation.FuncAnimation(fig, update, interval = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Interactivity

# %% [markdown]
# We need to inroduce canvas object which will handle all of the drawing events
#
# types of hardware events: moving and clicking the pointer, pressing key of keyward
#
# software events : java, html. piece of data is associated with function call. and it's an event

# %%
plt.figure()
data = np.random.rand(10)

def oneclick(event):
    plt.cla() #clear current plot
    plt.plot(data)
    #create event
    plt.gca().set_title('Event at pixels {}, {} {}and data {},{}'.format(event.x,
                                                                        event.y,
                                                                        '\n',
                                                                        event.xdata,
                                                                        event.ydata))
#connect the event object with listener

plt.gcf().canvas.mpl_connect('button_press_event', oneclick) #event:button_press_event
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %%
from random import shuffle
origins = ['China', 'Brazil', 'India', 'USA', 'Canada',
          'UK', 'Germany', 'Iraq', 'Chille', 'Maxico']

shuffle(origins)

df = pd.DataFrame({'Height': np.random.rand(10),
                  'Weight': np.random.rand(10),
                  'origin': origins})
df
# Out:
#      Height    Weight   origin
# 0  0.714077  0.091395   Brazil
# 1  0.403708  0.879006   Maxico
# 2  0.363862  0.784559   Canada
# 3  0.995801  0.932135       UK
# 4  0.198437  0.630926  Germany
# 5  0.089080  0.345331      USA
# 6  0.378914  0.034380    China
# 7  0.139872  0.170049   Chille
# 8  0.115517  0.055701     Iraq
# 9  0.670468  0.199886    India

# %%
plt.figure()
# picker=5 means the mouse doesn't have to click directly on an event, but can be up to 5 pixels away
plt.scatter(df['Height'], df['Weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))

# tell mpl_connect we want to pass a 'pick_event' into onpick when the event is detected
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7
