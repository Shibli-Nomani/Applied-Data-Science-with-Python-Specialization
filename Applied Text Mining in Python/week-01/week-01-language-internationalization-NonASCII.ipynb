# %% [markdown]
# # English and ASCII (American Standard Code for Information Interchange)

# %% [markdown]
# 1. 7 bits character  encoding standard
# 2. Including alphabets (upper case, lower case), digit, punctuation, common symbols ($, #), control characters(end of the sence, tab)
# 3. worked(relatively) well in English typewritting

# %% [markdown]
# **What is used to be enough for English may not be enough for decoding Diacritic and other international language**
# ![image.png](attachment:e9e39eda-e506-4c95-91ce-4f75fb61c81b.png)

# %% [markdown]
# <h2>Example of Résumé </h2>

# %%
text1 = 'Résumé'
len(text1)
# Out:
# 6

# %%
[c for c in text1]
# Out:
# ['R', 'é', 's', 'u', 'm', 'é']
