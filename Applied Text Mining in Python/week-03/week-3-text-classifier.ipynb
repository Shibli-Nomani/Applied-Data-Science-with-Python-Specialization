# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn import naive_bayes

# %%
clfnb = naive_bayes.MultinomialNB().fit(train_data, train_labels)

# %%
predicted_labels = clfnb.predict(test_data)

# %%
metrics.f1_score(test_labels, predicted_labels, average = 'micro')

# %% [markdown]
# # SVM Classifier

# %%
from sklearn import svm

# %% [markdown]
# Typically we use linear kernel for text classifier. and C is the parameter of soft margin

# %%
clfsvc = svm.SVC(kernel = "linear", C = 0.1).fit(train_data, train_labels)

# %%
predicted_labels = clfsvc.predict(test_data)

# %%
metrics.f1_score(test_labels, predicted_labels, average = 'micro')

# %% [markdown]
# ### Model Selection
#
# There are different phases of supervised learning task.
# 1. Training Phase
# 2. Inference Phase
#
# One: Model Selection By TrainTest Split with Validation data. But losing significant of data while validation
#
# Two: Cross Validation
#
# ![image.png](attachment:070f9839-6d2f-43dd-9711-b998c257ec72.png)

# %% [markdown]
# ### Model Selection by sklearn using train_test_split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# ### Model Selection by sklearn using cross_validate

# %%
from sklearn.model_selection import cross_validate

predicted_labels = cross_validation(clfsvc, X, y, cv = 5)

# %% [markdown]
# ### Supervised Text Classification in NLTK

# %% [markdown]
# some classification Algorithm of NLTK
#
# 1. Naive Bayes Classifier
# 2. ConditionalExponential Classifier
# 3. DecisionTree Classifier
# 4. Maxent Classifier
# 5. Weka Classifier
# 6. Sklearn Classifier

# %% [markdown]
# ### Using NLTK NaiveBayes Classifier

# %%
from nltk.classify import NaiveBayesClassifier

# %%
#model training
classifier = NaiveBayesClassifier.train(train_set)

#model predict

classifier.classify(unlabeled_instance)
classifier.classify_many(unlabeled_instance)

#model performance

nltk.classify.util.accuracy(classifier, test_set)


#for labels
classifier.labels()

classifier.show_most_informative_features()

# %% [markdown]
# ### Using NLTK SVM

# %%
from nltk.classify import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# %%
clfsvm = SklearnClassifier(MultinomialNB()).train(train_set)

# %%
clfsvm
