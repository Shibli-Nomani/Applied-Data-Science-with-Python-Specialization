# %% [markdown]
# # Assignment 3
#
# In this assignment you will explore measures of centrality on two networks, a friendship network in Part 1, and a blog network in Part 2.

# %% [markdown]
# ## Part 1
#
# Answer questions 1-4 using the network `G1`, a network of friendships at a university department. Each node corresponds to a person, and an edge indicates friendship.
#
# *The network has been loaded as networkx graph object `G1`.*

# %%
import networkx as nx

G1 = nx.read_gml('assets/friendships.gml')

# %%
nx.draw_networkx(G1)

# %% [markdown]
# ### Question 1
#
# Find the degree centrality, closeness centrality, and betweeness centrality of node 100.
#
# *This function should return a tuple of floats `(degree_centrality, closeness_centrality, betweenness_centrality)`.*

# %%
def answer_one():
    # YOUR CODE HERE
    import networkx as nx
    #degree_centrality
    dc = nx.degree_centrality(G1).get(100)
    #closeness_centrality
    cc = nx.closeness_centrality(G1).get(100)
    #betweenness_centrality
    bc = nx.betweenness_centrality(G1).get(100)
    return (dc, cc, bc)
    raise NotImplementedError()

# %%
ans_one = answer_one()
assert type(ans_one) == tuple, "You must return a tuple"

# %%
ans_one
# Out:
# (0.0026501766784452294, 0.2654784240150094, 7.142902633244772e-05)

# %% [markdown]
# ### Use centrality measures to answer questions 2-4

# %% [markdown]
# ### Question 2
#
# Suppose you are employed by an online shopping website and are tasked with selecting one user in network G1 to send an online shopping voucher to. We expect that the user who receives the voucher will send it to their friends in the network.  You want the voucher to reach as many nodes as possible. The voucher can be forwarded to multiple users at the same time, but the travel distance of the voucher is limited to one step, which means if the voucher travels more than one step in this network, it is no longer valid. Apply your knowledge in network centrality to select the best candidate for the voucher.
#
# *This function should return an integer, the chosen node.*

# %%
def answer_two():
    # YOUR CODE HERE
    #find node which have most degrees
    l = list(sorted(G1.degree, key=lambda x: x[1], reverse = True))
    #print(l[0])
    return list(l[0])[0]

    raise NotImplementedError()

# %%
ans_two = answer_two()

# %%
ans_two
# Out:
# 105

# %% [markdown]
# ### Question 3
#
# Now the limit of the voucher’s travel distance has been removed. Because the network is connected, regardless of who you pick, every node in the network will eventually receive the voucher. However, we now want to ensure that the voucher reaches nodes as quickly as possible (i.e. in the fewest number of hops). How will you change your selection strategy? Write a function to tell us who is the best candidate in the network under this condition.
#
# *This function should return an integer, the chosen node.*

# %%
def answer_three():
    # YOUR CODE HERE
    closeness = sorted(nx.closeness_centrality(G1).items(), key=lambda x:x[1], reverse =True)
    max_closeness = closeness[0]
    #max_closeness
    
    max_closeness[0]
    
    return max_closeness[0]
    
    raise NotImplementedError()

# %%
ans_three = answer_three()

# %%
ans_three
# Out:
# 23

# %% [markdown]
# ### Question 4
#
# Assume the restriction on the voucher’s travel distance is still removed, but now a competitor has developed a strategy to remove a person from the network in order to disrupt the distribution of your company’s voucher. You competitor plans to remove people who act as bridges in the network. Identify the best possible person to be removed by your competitor?
#
# *This function should return an integer, the chosen node.*

# %%
def answer_four():
    # YOUR CODE HERE
    betweenness = sorted(nx.betweenness_centrality(G1).items(), key=lambda x:x[1], reverse = True)

    max_betweenness = betweenness[0]

    return max_betweenness[0]
    raise NotImplementedError()

# %%
ans_four = answer_four()

# %%
ans_four
# Out:
# 333

# %% [markdown]
# ## Part 2
#
# `G2` is a directed network of political blogs, where nodes correspond to a blog and edges correspond to links between blogs. Use your knowledge of PageRank and HITS to answer Questions 5-9.

# %%
G2 = nx.read_gml('assets/blogs.gml')

# %%
nx.draw_networkx(G2)

# %% [markdown]
# ### Question 5
#
# Apply the Scaled Page Rank Algorithm to this network. Find the Page Rank of node 'realclearpolitics.com' with damping value 0.85.
#
# *This function should return a float.*

# %%
def answer_five():
    # YOUR CODE HERE
    pageRank = nx.pagerank(G2, alpha = 0.85)
    return pageRank.get( 'realclearpolitics.com')
    raise NotImplementedError()

# %%
ans_five = answer_five()

# %%
ans_five
# Out:
# 0.004636694781649098

# %% [markdown]
# ### Question 6
#
# Apply the Scaled Page Rank Algorithm to this network with damping value 0.85. Find the 5 nodes with highest Page Rank.
#
# *This function should return a list of the top 5 blogs in desending order of Page Rank.*

# %%
def answer_six():
    # YOUR CODE HERE
    pageRank = nx.pagerank(G2, alpha = 0.85)
    max_pr = sorted(pageRank.items(), key = lambda x:x[1], reverse = True)
    #max_pr[0:5]
    top5 = list(dict(max_pr[0:5]).keys())
    return top5
    raise NotImplementedError()

# %%
ans_six = answer_six()
assert type(ans_six) == list, "You must return a list"

# %%
ans_six
# Out:
# ['dailykos.com',
#  'atrios.blogspot.com',
#  'instapundit.com',
#  'blogsforbush.com',
#  'talkingpointsmemo.com']

# %% [markdown]
# ### Question 7
#
# Apply the HITS Algorithm to the network to find the hub and authority scores of node 'realclearpolitics.com'.
#
# *Your result should return a tuple of floats `(hub_score, authority_score)`.*

# %%
def answer_seven():
    # YOUR CODE HERE
    #hits algorithm for hub and authority score
    
    hub_score, authority_score = nx.hits(G2)

    h = hub_score.get('realclearpolitics.com')
    a = authority_score.get('realclearpolitics.com')
    
    return (h, a)
    raise NotImplementedError()

# %%
ans_seven = answer_seven()
assert type(ans_seven) == tuple, "You must return a tuple"

# %%
ans_seven
# Out:
# (0.0003243556140278733, 0.003918957644934256)

# %% [markdown]
# ### Question 8
#
# Apply the HITS Algorithm to this network to find the 5 nodes with highest hub scores.
#
# *This function should return a list of the top 5 blogs in desending order of hub scores.*

# %%
def answer_eight():
    # YOUR CODE HERE
    hub_scores, authority_scores = nx.hits(G2)
    hubs = sorted(hub_scores.items(), key = lambda x:x[1], reverse = True)
    #dict(hubs[0:5])
    #dict(hubs[0:5]).keys()
    #top5 blogs based on hub_scores
    top5_blogs = list(dict(hubs[0:5]).keys())
    return top5_blogs
    raise NotImplementedError()

# %%
ans_eight = answer_eight()
assert type(ans_eight) == list, "You must return a list"

# %%
ans_eight
# Out:
# ['politicalstrategy.org',
#  'madkane.com/notable.html',
#  'liberaloasis.com',
#  'stagefour.typepad.com/commonprejudice',
#  'bodyandsoul.typepad.com']

# %% [markdown]
# ### Question 9
#
# Apply the HITS Algorithm to this network to find the 5 nodes with highest authority scores.
#
# *This function should return a list of the top 5 blogs in desending order of authority scores.*

# %%
def answer_nine():
    # YOUR CODE HERE
    hub_scores, authority_scores = nx.hits(G2)

    authority = sorted(authority_scores.items(), key = lambda x : x[1], reverse = True)
    #authority[0:5]
    #dict(authority[0:5])
    #dict(authority[0:5]).keys()
    authority_top5 = list(dict(authority[0:5]).keys())
    return authority_top5
    raise NotImplementedError()

# %%
ans_nine = answer_nine()
assert type(ans_nine) == list, "You must return a list"

# %%
ans_nine
# Out:
# ['dailykos.com',
#  'talkingpointsmemo.com',
#  'atrios.blogspot.com',
#  'washingtonmonthly.com',
#  'talkleft.com']
